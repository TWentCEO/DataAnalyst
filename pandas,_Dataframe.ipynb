# %% [markdown]
# <a href="https://colab.research.google.com/github/TWentCEO/DataAnalyst/blob/main/pandas%2C_Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame()
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
stu_list = [['Michael', 'John', 'jennie', 'Susan'], [19, 18, 17, 16]]
print(stu_list)
# Out:
# [['Michael', 'John', 'jennie', 'Susan'], [19, 18, 17, 16]]

# %%
df = pd.DataFrame(stu_list)
df
# Out:
#          0     1       2      3
# 0  Michael  John  jennie  Susan
# 1       19    18      17     16

# %%
df = df.T
df
# Out:
#          0   1
# 0  Michael  19
# 1     John  18
# 2   jennie  17
# 3    Susan  16

# %%
df.columns = ['name', 'age']
df
# Out:
#       name age
# 0  Michael  19
# 1     John  18
# 2   jennie  17
# 3    Susan  16
